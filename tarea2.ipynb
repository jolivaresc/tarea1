# %%
from nltk import TweetTokenizer
import re
import numpy as np
from collections import Counter

# %% [markdown]
# # Funciones
#
# * `remove_mentions()`: Cambia las menciones por un token genérico (@usuario)
# * `twitter_url_re`: REGEX para URLs

# %%
def remove_mentions(text):
    """
    Remove Twitter username handles from text.
    """
    pattern = re.compile(r"(?<![A-Za-z0-9_!@#\$%&*])@(([A-Za-z0-9_]){20}(?!@))|(?<![A-Za-z0-9_!@#\$%&*])@(([A-Za-z0-9_]){1,19})(?![A-Za-z0-9_]*@)")
    # Substitute hadnles with '@USUARIO' to ensure that text on either side of removed handles are tokenized correctly
    return pattern.sub('@usuario', text)
"""
Regex para URLs
"""
twitter_url_re = re.compile(r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+')

# %% [markdown]
# # Testings

# %%
"""
Testings
"""
tweet_ficticio = 'RT @marcobonzanini: just an Axampleeeeeeee! :D http://example.com #NLP' 

tweet_ficticio = remove_mentions(tweet_ficticio) 


"""
preserve_false: cambia todo a minúsculas
reduce_len: Elimina caracteres que estén repetidos más de 3 veces
"""
tknzr = TweetTokenizer(reduce_len=True,preserve_case=False) 


tweet_tokenized = tknzr.tokenize(tweet_ficticio)

for i in range(len(tweet_tokenized)):
    if re.match(twitter_url_re,tweet_tokenized[i]):
        tweet_tokenized[i] = 'url' # Cambia una dirección URL por un token genérico

print(tweet_ficticio)  # Tweet original
print(tweet_tokenized) # Tweet tokenizado
# Out:
# RT @usuario: just an Axampleeeeeeee! :D http://example.com #NLP
# ['rt', '@usuario', ':', 'just', 'an', 'axampleee', '!', ':D', 'url', '#nlp']

# %%
"""
Bandera para indicar que el corpus ya se preprocesó
"""
FLAG1 = True

# %% [markdown]
# # Preprocesamiento de tweets
# * Se tokenizan los tweets y se cambian algunos tokens según la lista `stopwords`.
# * Se contabilizan los tokens.
# * Se escriben los tweets preprocesados en un nuevos archivo.
# * Se contabilizan las frecuencias de los tokens en un diccionario por órden ascendente de aparación.

# %%
if not FLAG1:
    """
    Archivos
    """
    tmp_corpus = 'tmp_corpus.txt'
    tweets_corpus = 'solo_espanol.txt'


    """
    preserve_false: Cambia todo a minúsculas
    reduce_len: Elimina caracteres que estén repetidos más de 3 veces
    """
    tknzr = TweetTokenizer(reduce_len=True,preserve_case=False)


    """
    _types: diccionario para almacenar los tipos del corpus
    _tokens: lista para almacenar los tokens del corpus
    """
    _types,_tokens={},[]
    new_tmp = 'new_tmp_corpus.txt'

    new_corpus = open(new_tmp,'w+',encoding='utf-8')


    """
    Stopwords
    """
    stop_list = ["caracterdesaltodelínea",".","..","...",
                 "?","¿",",","(",")","'","!","¡",'"',";",
                 ":","->","/","-","--->","…"]

    """
    Leer y preprocesar corpus
    """


    with open(tweets_corpus,'r',encoding='utf-8') as corpus:

        # Cada línea del corpus es un tweet
        for line in corpus:

            line = remove_mentions(line) # Sustituir mención de usuario por un token genérico        
            tweet = tknzr.tokenize(line)[:-1] # Quitar etiqueta 'es' de cada tweet
            tweet = [_ for _  in tweet if _ not in stop_list] # Eliminar Tokens 'innecesarios'

            for token in range(len(tweet)):

                # Compara si el token es una URL
                if re.match(twitter_url_re,tweet[token]):

                    tweet[token] = 'url' # Sustituir dirección url por token URL
                    _tokens.append(tweet[token])

                # Cambia números por token genérico    
                if tweet[token].replace(".", "", 1).isdigit():
                    tweet[token] = '_number'
                    _tokens.append(tweet[token])

                _tokens.append(tweet[token])

            #print(tweet)
            new_corpus.write(" ".join(tweet))
            new_corpus.write("\n")
            #print(' '.join(tweet),end="\n")

    new_corpus.close()
    
    """
    Obtener las frecuencias de los tweets
    """
    _types = dict(Counter(_tokens))
    n_tokens, n_types = len(_tokens), len(_types) # Número de types y tokens
    
    types = sorted(_types.items(), key=lambda x: x[1],reverse=True) # Ordenar types por frecuencia

# %% [markdown]
# # Guardar types en un archivo
# Guardar types y ordenar por frecuencia de aparición

# %%
if not FLAG1:
    file_types = open("file_types.txt","w+",encoding="utf-8")

    for i in types:
        file_types.write(str(i[0])+ " " + str(i[1]))
        file_types.write("\n")    
    file_types.close()

# %%
word_of_interest = 'excelente'


with open("new_tmp_corpus.txt",'r', encoding='utf-8') as file:
    for line in file:
        tweet = tknzr.tokenize(line)
        
        if word_of_interest in tweet:
            print(tweet[tweet.index(word_of_interest) - 1:tweet.index(word_of_interest) + 2])
# Out:
# []
# ['un', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'inicio']
# ['y', 'excelente', 'semana']
# ['y', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'infornacion']
# ['servirle', 'excelente', 'día']
# ['estrella', 'excelente', 'lunes']
# ['@usuario', 'excelente', 'intervención']
# []
# ['tmb', 'excelente', 'intervención']
# ['un', 'excelente', 'comienzo']
# ['días', 'excelente', 'lunes']
# ['una', 'excelente', 'semana']
# ['días', 'excelente', 'inicio']
# ['un', 'excelente', 'y']
# ['retos', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'semana']
# ['dijo', 'excelente', 've']
# ['retos', 'excelente', 'inicio']
# ['días', 'excelente', 'lunes']
# ['con', 'excelente', 'infor']
# ['un', 'excelente', 'munes']
# ['un', 'excelente', 'inicio']
# ['una', 'excelente', 'semana']
# ['un', 'excelente', 'inicio']
# ['días', 'excelente', 'inicio']
# ['un', 'excelente', 'día']
# ['igualmente', 'excelente', 'inicio']
# ['una', 'excelente', 'noticia']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# []
# ['une', 'excelente', 'día']
# []
# ['deseamos', 'excelente', 'inicio']
# []
# []
# ['servirle', 'excelente', 'día']
# ['con', 'excelente', 'informacio']
# ['una', 'excelente', 'tarde']
# ['servirle', 'excelente', 'día']
# []
# ['atención', 'excelente', 'atención']
# ['pases', 'excelente', 'lunes']
# []
# ['@usuario', 'excelente', 'escucharte']
# ['servirle', 'excelente', 'día']
# ['miedo', 'excelente', 'inicio']
# ['con', 'excelente', 'informacion']
# ['tenga', 'excelente', 'inicio']
# []
# ['#saludentuescuela', 'excelente', 'iniciativa']
# ['una', 'excelente', 'tarde']
# []
# ['aplica', 'excelente', 'saludos']
# ['una', 'excelente', 'semana']
# ['tengan', 'excelente', 'gira']
# ['argentina', 'excelente', 'trabajo']
# []
# ['week', 'excelente', 'semana']
# ['de', 'excelente', 'música']
# []
# []
# []
# ['un', 'excelente', 'inicio']
# ['una', 'excelente', 'reunión']
# []
# ['mami', 'excelente', 'solo']
# ['con', 'excelente', 'informacion']
# ['portarme', 'excelente', 'creo']
# ['será', 'excelente', 'como']
# ['una', 'excelente', 'noche']
# ['el', 'excelente', 'vídeo']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'confío']
# ['@usuario', 'excelente', 'noticia']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'tuit']
# ['@usuario', 'excelente', 'pu']
# []
# ['un', 'excelente', 'coach']
# []
# ['un', 'excelente', 'parteaguas']
# ['café', 'excelente', 'combinación']
# []
# ['#dj', 'excelente', '#música']
# []
# ['pedregal', 'excelente', 'noche']
# []
# ['un', 'excelente', 'inicio']
# ['está', 'excelente', '@usuario']
# ['@usuario', 'excelente', 'proyecto']
# ['@usuario', 'excelente', '👏']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'lucha']
# []
# ['bellisima', 'excelente', 'pograma']
# ['bellisima', 'excelente', 'pograma']
# ['@usuario', 'excelente', 'proyecto']
# ['carthys', 'excelente', 'opción']
# ['bellisima', 'excelente', 'pograma']
# []
# []
# ['el', 'excelente', 'viaje']
# []
# ['un', 'excelente', 'remedio']
# ['tengan', 'excelente', 'martes']
# []
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['y', 'excelente', 'martes']
# ['y', 'excelente', 'inform']
# ['con', 'excelente', 'informacion']
# [':)', 'excelente', 'martes']
# ['@s', 'excelente', 'martes']
# ['guapos', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['sea', 'excelente', 'y']
# ['un', 'excelente', 'martes']
# ['cosita', 'excelente', 'día']
# ['campeón', 'excelente', 'día']
# ['@usuario', 'excelente', 'abrazos']
# ['con', 'excelente', 'informacion']
# []
# ['muchachos', 'excelente', 'arranque']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'y']
# []
# ['🙌', 'excelente', 'día']
# ['un', 'excelente', 'martes']
# []
# ['gracias', 'excelente', 'día']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# []
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'fía']
# ['un', 'excelente', 'martes']
# ['y', 'excelente', 'semana']
# ['amiga', 'excelente', 'día']
# ['@usuario', 'excelente', 'pensamiento']
# []
# ['una', 'excelente', 'semana']
# ['poder', 'excelente', 'día']
# ['un', 'excelente', 'martes']
# []
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['bellisima', 'excelente', 'informacion']
# ['un', 'excelente', 'administrador']
# ['un', 'excelente', 'martes']
# ['_number', 'excelente', 'martes']
# ['un', 'excelente', 'sueldo']
# []
# []
# ['saludos', 'excelente', 'la']
# ['un', 'excelente', 'y']
# []
# ['la', 'excelente', 'promoción']
# ['tiene', 'excelente', 'reputación']
# ['una', 'excelente', 'tarde']
# ['realidad', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['url', 'excelente', 'por']
# ['un', 'excelente', 'futuro']
# ['imperdible', 'excelente', 'trabajo']
# ['con', 'excelente', 'informacion']
# []
# []
# ['un', 'excelente', 'padrino']
# ['respeto', 'excelente', 'charla']
# ['servirle', 'excelente', 'tarde']
# ['@usuario', 'excelente', '#facial']
# ['@usuario', 'excelente', 'programa']
# ['@usuario', 'excelente', 'entrevista']
# ['@usuario', 'excelente', 'entrevista']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'opción']
# ['una', 'excelente', 'actriz']
# ['una', 'excelente', 'actriz']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['junio', 'excelente', 'periodo']
# ['esta', 'excelente', 'pelicula']
# []
# []
# ['es', 'excelente', 'que']
# ['😘', 'excelente', 'martes']
# ['martes', 'excelente', 'track']
# ['es', 'excelente', 'que']
# ['este', 'excelente', 'disco']
# ['pero', 'excelente', 'coincidencia']
# []
# []
# ['siempre', 'excelente', 'servicio']
# ['una', 'excelente', 'noche']
# ['pinta', 'excelente', 'sólo']
# []
# ['una', 'excelente', 'noche']
# ['otro', 'excelente', 'día']
# ['una', 'excelente', 'noche']
# ['eres', 'excelente', 'y']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'martes']
# ['una', 'excelente', 'noche']
# ['cordiales', 'excelente', 'noche']
# []
# ['un', 'excelente', 'día']
# ['una', 'excelente', 'noche']
# ['todo', 'excelente']
# ['un', 'excelente', 'candidato']
# ['bellisima', 'excelente', 'pograma']
# []
# ['una', 'excelente', 'noche']
# []
# ['bellisima', 'excelente', 'informacion']
# ['guapa', 'excelente', 'grupo']
# ['bellisima', 'excelente', 'conductora']
# []
# ['película', 'excelente', 'además']
# ['#lateoriadeltodo', 'excelente', 'película']
# ['y', 'excelente', 'sólo']
# ['\U0001f923', 'excelente', 'tuit']
# ['daughters', 'excelente', 'película']
# ['encanta', 'excelente', 'miércoles']
# ['☺', 'excelente', 'miércoles']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['bellisima', 'excelente', 'in']
# ['bellisima', 'excelente', 'informacion']
# ['un', 'excelente', 'miércoles']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'serie']
# ['sueño', 'excelente', 'miércoles']
# ['bellisima', 'excelente', 'informacion']
# ['un', 'excelente', 'día']
# []
# ['temas', 'excelente', 'día']
# ['@usuario', 'excelente', 'atención']
# []
# []
# ['@usuario', 'excelente', 'día']
# ['una', 'excelente', 'oportunid']
# ['un', 'excelente', 'miércoles']
# []
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['@usuario', 'excelente', 'miercoles']
# ['un', 'excelente', 'miércoles']
# ['día', 'excelente', 'miércoles']
# ['😘', 'excelente', '#miercoles']
# []
# ['una', 'excelente', 'jornada']
# ['con', 'excelente', 'informacion']
# []
# ['una', 'excelente', 'actitud']
# ['un', 'excelente', 'miérc']
# ['servirle', 'excelente', 'día']
# ['día']
# []
# ['un', 'excelente', 'miércoles']
# []
# ['️', 'excelente', 'día']
# ['una', 'excelente', 'idea']
# ['ustedes', 'excelente', 'miércoles']
# ['días', 'excelente', 'miércoles']
# ['es', 'excelente', '😀']
# []
# ['@s', 'excelente', 'miércoles']
# ['un', 'excelente', 'día']
# ['interés', 'excelente', 'día']
# ['@usuario', 'excelente', 'definición']
# ['@usuario', 'excelente', 'charla']
# ['un', 'excelente', 'dia']
# []
# ['olivia', 'excelente', 'programación']
# ['axel', 'excelente', 'miércoles']
# ['una', 'excelente', 'manera']
# ['tengan', 'excelente', 'día']
# []
# ['josely', 'excelente', 'día']
# ['@usuario', 'excelente', 'consigna']
# ['tengas', 'excelente', 'mitad']
# []
# []
# []
# ['este', 'excelente', 'video']
# ['frase', 'excelente', 'ombligo']
# ['estuvo', 'excelente', 'la']
# ['@usuario', 'excelente', 'exposición']
# ['éxito', 'excelente', 'conferencia']
# ['@usuario', 'excelente', 'mesa']
# ['buscando', 'excelente', 'oportunidad']
# ['con', 'excelente', 'informaci']
# ['durán', 'excelente', 'pero']
# ['pendiente', 'excelente', 'día']
# []
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'miércoles']
# []
# ['cabrones', 'excelente', 'miércoles']
# ['@usuario', 'excelente', 'gracias']
# ['una', 'excelente', 'noche']
# ['el', 'excelente', 'servicio']
# ['@usuario', 'excelente', 'postre']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'noche']
# ['es', 'excelente']
# []
# ['digo', 'excelente', 'jugador']
# ['una', 'excelente', 'utilidad']
# []
# ['un', 'excelente', 'cantante']
# ['@usuario', 'excelente']
# ['y', 'excelente', 'noche']
# ['@usuario', 'excelente', 'trabajo']
# ['parece', 'excelente', 'tu']
# []
# ['. . .', 'excelente', 'noche']
# ['@usuario', 'excelente', 'crónica']
# ['mucho', 'excelente', 'trabajo']
# ['una', 'excelente', 'experiencia']
# ['fue', 'excelente', 'dia']
# []
# ['un', 'excelente', 'día']
# ['pinta', 'excelente', 'gracias']
# ['con', 'excelente', 'conductora']
# ['@usuario', 'excelente', '#nochemágica']
# []
# ['munira', 'excelente', 'programa']
# ['munira', 'excelente', 'programa']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['la', 'excelente', 'banda']
# ['un', 'excelente', 'día']
# ['una', 'excelente', 'relación']
# ['gracias', 'excelente', 'cuenta']
# ['un', 'excelente', 'jueves']
# ['cordiales', 'excelente', 'jueves']
# []
# ['un', 'excelente', 'falsificador']
# ['días', 'excelente', 'jueves']
# ['sueños', 'excelente', 'jueves']
# ['rodolfo', 'excelente', 'url']
# ['con', 'excelente', 'informacion']
# []
# []
# []
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'día']
# ['sea', 'excelente', 'en']
# ['y', 'excelente', 'jueves']
# ['tengas', 'excelente', 'día']
# ['tengas', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'informacion']
# ['reciclaje', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'y']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'inform']
# ['con', 'excelente', 'informacion']
# ['#flyeaglesfly', 'excelente', 'texto']
# ['nublado', 'excelente']
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'día']
# ['y', 'excelente', 'jueves']
# ['siguiente', 'excelente', 'día']
# ['hermosa', 'excelente', 'informacion']
# ['🏼', 'excelente', 'texto']
# ['@usuario', 'excelente', 'día']
# ['tengan', 'excelente', 'jueves']
# ['todos', 'excelente', 'juevesito']
# ['un', 'excelente', 'jueves']
# []
# ['un', 'excelente', 'día']
# []
# ['pd', 'excelente', 'servicio']
# ['un', 'excelente', 'evento']
# ['udeei', 'excelente', 'equipo']
# ['un', 'excelente', 'programa']
# ['un', 'excelente', 'jueves']
# []
# ['bendiga', 'excelente', '…']
# []
# []
# ['una', 'excelente', 'iniciativa']
# ['y', 'excelente', 'jueves']
# []
# ['un', 'excelente', 'día']
# []
# ['propuesta', 'excelente', 'día']
# ['@usuario', 'excelente', 'razonamiento']
# []
# ['tengas', 'excelente', 'y']
# []
# ['con', 'excelente', 'informacio']
# []
# ['un', 'excelente', 'amigo']
# ['salió', 'excelente', 'en']
# ['otra', 'excelente', 'noticia']
# ['un', 'excelente', 'actor']
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'se']
# ['una', 'excelente', 'tarde']
# []
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'fotografía']
# ['con', 'excelente', 'entrevista']
# ['pases', 'excelente', 'jueves']
# ['@usuario', 'excelente', '😅']
# []
# []
# ['queda', 'excelente', '#bama2017diamondedition_bigbang']
# ['@usuario', 'excelente', 'tarde']
# ['de', 'excelente', 'ambiente']
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'jueves']
# ['una', 'excelente', 'tarde']
# ['🏼', 'excelente', '#entrenamiento']
# []
# ['|', 'excelente', 'comida']
# ['tengo', 'excelente', 'música']
# ['una', 'excelente', 'noche']
# ['bellisima', 'excelente', 'informacion']
# ['un', 'excelente', 'equipo']
# []
# ['@usuario', 'excelente', 'persona']
# []
# ['una', 'excelente', 'tarde']
# []
# ['sale', 'excelente', '…']
# []
# []
# ['bellisima', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['es', 'excelente']
# ['tengas', 'excelente', 'noche']
# ['@usuario', 'excelente', 'servicio']
# []
# []
# ['el', 'excelente', 'texto']
# ['un', 'excelente', 'lugar']
# ['la', 'excelente', 'compañía']
# ['@usuario', 'excelente', 'palabra']
# ['miyana', 'excelente', 'comida']
# ['@usuario', 'excelente', 'planteamiento']
# ['un', 'excelente', 'cantante']
# ['un', 'excelente', 'día']
# ['es', 'excelente', 'portero']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# []
# ['jugador', 'excelente', '@usuario']
# ['esta', 'excelente', 'se']
# ['un', 'excelente', 'comediante']
# ['un', 'excelente', 'viernes']
# ['eres', 'excelente', 'me']
# ['gracias', 'excelente', 'tiempo']
# ['mi', 'excelente', 'currículum']
# ['eres', 'excelente', 'conductora']
# []
# ['🙌', 'excelente', 'análisis']
# ['una', 'excelente', 'noche']
# ['tan', 'excelente', 'comienzo']
# ['y', 'excelente', 'compañía']
# ['👋', 'excelente', 'mañana']
# []
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'viernes']
# ['noticiero', 'excelente', 'viernes']
# []
# ['una', 'excelente', 'jornada']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['presente', 'excelente', 'manera']
# ['un', 'excelente', 'día']
# ['y', 'excelente', 'fin']
# []
# ['pases', 'excelente', 'fin']
# []
# ['con', 'excelente', 'encuentas']
# []
# ['tengas', 'excelente', 'día']
# []
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['pases', 'excelente', 'fin']
# ['@usuario', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'fin']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['😃', 'excelente', 'fin']
# ['con', 'excelente', 'informacion']
# []
# ['un', 'excelente', 'cumple']
# ['destino', 'excelente', 'para']
# []
# ['tengan', 'excelente', 'viernes']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'y']
# ['tengas', 'excelente', 'fin']
# ['un', 'excelente', 'cierre']
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'respuesta']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'fin']
# ['un', 'excelente', 'dia']
# ['un', 'excelente', 'fin']
# ['historica', 'excelente', 'viernes']
# ['#queremosrock', 'excelente', 'día']
# ['@usuario', 'excelente', 'ponencia']
# []
# ['favor', 'excelente', 'martes']
# ['pases', 'excelente', 'en']
# ['cierto', 'excelente', 'viernes']
# ['una', 'excelente', 'tarde']
# []
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'viernes']
# ['fue', 'excelente']
# ['un', 'excelente', 'fin']
# ['que', 'excelente', 'noche']
# []
# ['@usuario', 'excelente', 'decisión']
# []
# ['una', 'excelente', 'compañía']
# ['una', 'excelente', 'noticia']
# ['usa', 'excelente', 'opción']
# ['pasen', 'excelente', 'viernes']
# ['eres', 'excelente', 'conductora']
# ['un', 'excelente', 'día']
# ['amigo', 'excelente', 'fin']
# ['una', 'excelente', 'recomendación']
# ['deseándoles', 'excelente', 'y']
# ['y', 'excelente', 'fin']
# []
# []
# []
# []
# []
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'tarde']
# ['@usuario', 'excelente', 'presentación']
# []
# ['una', 'excelente', 'noche']
# ['chula', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# []
# []
# ['lugar', 'excelente', 'para']
# ['y', 'excelente', 'fin']
# ['una', 'excelente', 'noche']
# ['con', 'excelente', 'servicio']
# ['pases', 'excelente', 'fin']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'dia']
# []
# ['el', 'excelente', 'trabajo']
# ['@usuario', 'excelente', 'idea']
# []
# []
# ['@usuario', 'excelente', 'reflexión']
# ['otro', 'excelente', 'día']
# []
# []
# ['su', 'excelente', 'programa']
# []
# ['con', 'excelente', 'compañía']
# ['un', 'excelente', 'viernes']
# []
# ['y', 'excelente', 'informacion']
# ['menú', 'excelente', 'la']
# []
# ['siempre', 'excelente', 'tu']
# ['@usuario', 'excelente', 'te']
# ['encantó', 'excelente', 'artículo']
# ['un', 'excelente', 'día']
# []
# ['que', 'excelente', 'actuación']
# ['con', 'excelente', 'compañía']
# ['día', 'excelente', 'para']
# ['url', 'excelente']
# ['bella', 'excelente', 'frase']
# ['#buenosdias', 'excelente', 'sabado']
# ['sea', 'excelente', 'fin']
# ['@usuario', 'excelente', 'información']
# []
# ['un', 'excelente', 'sábado']
# ['sea', 'excelente', '…']
# ['😋', 'excelente', 'día']
# []
# ['una', 'excelente', 'dosis']
# ['con', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'informacion']
# []
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'presentación']
# ['un', 'excelente', 'equipo']
# ['pagar', 'excelente', 'modelo']
# ['@usuario', 'excelente', '@usuario']
# ['una', 'excelente', 'rutina']
# []
# []
# ['saludos', 'excelente', 'sábado']
# []
# []
# []
# ['y', 'excelente', 'sábado']
# []
# []
# ['sol', 'excelente', 'mañana']
# ['@usuario', 'excelente', 'que']
# ['un', 'excelente', 'sabado']
# ['un', 'excelente', 'fin']
# []
# ['una', 'excelente', 'hermana']
# ['un', 'excelente', 'día']
# []
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'sábado']
# ['más', 'excelente', 'enserio']
# []
# ['un', 'excelente', 'análisis']
# ['uno', 'excelente', 'chicos']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacio']
# ['#pueblomágico', 'excelente', 'sitio']
# ['día', 'excelente', 'fin']
# []
# ['comida', 'excelente', 'url']
# ['una', 'excelente', 'opción']
# ['tore', 'excelente', 'estancia']
# ['mejor', 'excelente']
# []
# []
# ['@usuario', 'excelente', 'foto']
# ['un', 'excelente', 'sábado']
# []
# ['temporada', 'excelente', 'de']
# ['la', 'excelente', 'compañía']
# ['una', 'excelente', 'tarde']
# []
# ['una', 'excelente', 'noche']
# []
# ['comida', 'excelente', 'charla']
# ['una', 'excelente', 'opción']
# ['@usuario', 'excelente', 'contenido']
# ['jejejeje', 'excelente', 'fin']
# ['y', 'excelente', 'ambiente']
# ['un', 'excelente', 'dia']
# []
# ['@usuario', 'excelente', 'participación']
# ['@usuario', 'excelente', 'participación']
# ['obstáculos', 'excelente', 'desempeño']
# ['@usuario', 'excelente', 'lugar']
# []
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'película']
# ['una', 'excelente', 'noche']
# ['día', 'excelente', 'al']
# ['📺', 'excelente', 'transmisión']
# ['una', 'excelente', 'noche']
# ['supuesto', 'excelente', 'director']
# ['@usuario', 'excelente', 'programa']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'escenografía']
# []
# ['@usuario', 'excelente', 'show']
# ['un', 'excelente', 'programa']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'sábado']
# []
# ['fm', 'excelente', 'noticia']
# ['#farandula40recargada', 'excelente', 'programa']
# ['saludos', 'excelente', 'concierto']
# ['@usuario', 'excelente', 'programa']
# ['y', 'excelente', 'primer']
# ['@usuario', 'excelente', 'comoda']
# ['🌟', 'excelente', 'felicidades']
# ['@usuario', 'excelente', 'comida']
# []
# ['dormir', 'excelente', '😴']
# ['una', 'excelente', 'luna']
# ['bellisima', 'excelente', 'conductora']
# ['y', 'excelente', 'conductora']
# ['haces', 'excelente', 'url']
# ['sido', 'excelente', '💕']
# ['una', 'excelente', 'muestra']
# []
# ['@usuario', 'excelente', 'trabajo']
# ['un', 'excelente', 'domingo']
# ['un', 'excelente', 'día']
# ['días', 'excelente', 'día']
# []
# []
# ['días', 'excelente', 'día']
# ['@usuario', 'excelente', 'fin']
# ['y', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['méxico', 'excelente', 'domingo']
# []
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['consejo', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'domingo']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'domingo']
# ['un', 'excelente', 'domingo']
# ['desayunar', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['@usuario', 'excelente', 'selección']
# ['un', 'excelente', 'video']
# ['un', 'excelente', 'y']
# ['un', 'excelente', '#domingo']
# []
# ['#felizdomingo', 'excelente', 'ocasión']
# []
# ['nena', 'excelente', 'idea']
# []
# ['faltes', 'excelente', 'oportunidad']
# ['tengan', 'excelente', 'domingo']
# []
# ['una', 'excelente', 'tarde']
# ['saludos', 'excelente', 'trasmicion']
# ['saludos', 'excelente', 'trasmicion']
# ['un', 'excelente', 'domingo']
# ['un', 'excelente', 'domingo']
# ['@usuario', 'excelente', 'texto']
# ['@usuario', 'excelente', 'carrera']
# []
# ['amiga', 'excelente', 'domingo']
# []
# []
# ['anunciando', 'excelente', 'proyecto']
# []
# []
# []
# ['una', 'excelente', 'función']
# ['@usuario', 'excelente', 'actuación']
# ['lo', 'excelente', 'piloto']
# ['una', 'excelente', 'compañía']
# ['con', 'excelente', 'informacion']
# ['lo', 'excelente', 'persona']
# ['una', 'excelente', 'tarde']
# ['pasamos', 'excelente', '❤']
# ['pase', 'excelente', 'pendientes']
# []
# []
# ['y', 'excelente', 'la']
# ['una', 'excelente', 'idea']
# ['una', 'excelente', 'inversión']
# ['marggie', 'excelente', 'tarde']
# ['#indy500', 'excelente', 'performance']
# ['igualmente', 'excelente', 'día']
# ['tarde', 'excelente', 'estoy']
# ['mexicano', 'excelente', 'lugar']
# ['la', 'excelente', 'atención']
# ['día', 'excelente', '@']
# []
# []
# ['amistades', 'excelente', 'atardecer']
# ['un', 'excelente', 'periodista']
# ['una', 'excelente', 'noche']
# ['amiga', 'excelente', 'domingo']
# ['que', 'excelente', 'cómo']
# ['cordiales', 'excelente', 'atardecer']
# ['un', 'excelente', 'juego']
# ['una', 'excelente', 'noche']
# ['tardes', 'excelente', 'domingo']
# ['una', 'excelente', 'recuperación']
# ['siente', 'excelente', 'regresar']
# []
# ['@usuario', 'excelente', 'programa']
# ['cordiales', 'excelente', 'domingo']
# ['cordiales', 'excelente', 'domingo']
# ['un', 'excelente', 'domingo']
# []
# []
# ['su', 'excelente', 'obra']
# ['acomodó', 'excelente', 'xd']
# ['un', 'excelente', 'entrenador']
# ['un', 'excelente', 'fin']
# ['una', 'excelente', 'noche']
# ['😍', 'excelente', 'cartón']
# ['una', 'excelente', 'noche']
# ['y', 'excelente', 'platica']
# []
# []
# ['un', 'excelente', 'domingo']
# ['es', 'excelente', 'aprovecha']
# ['una', 'excelente', 'noche']
# ['😊', 'excelente', 'inicio']
# ['huevis', 'excelente', 'semana']
# ['tu', 'excelente', 'trabajo']
# ['tu', 'excelente', 'desempeño']
# []
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'plan']
# ['una', 'excelente', 'y']
# ['una', 'excelente', 'y']
# ['una', 'excelente', 'y']
# []
# []
# ['y', 'excelente', 'inicio']
# []
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'hoy']
# []
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'decoración']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'día']
# ['@usuario', 'excelente', 'inicio']
# ['un', 'excelente', 'inició']
# ['#buenlunes', 'excelente', 'inicio']
# ['#buenlunes', 'excelente', 'inicio']
# ['todos', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['y', 'excelente', 'lunes']
# ['@usuario', 'excelente', 'dia']
# ['y', 'excelente', 'informacion']
# ['un', 'excelente', 'comienzo']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'comienzo']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'comienzo']
# []
# ['días', 'excelente', 'inicio']
# ['😜', 'excelente', '…']
# ['@usuario', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['tengas', 'excelente', 'semana']
# ['un', 'excelente', 'comienzo']
# ['y', 'excelente', 'inicio']
# []
# []
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['🏻', 'excelente', 'narración']
# []
# ['un', 'excelente', 'día']
# ['una', 'excelente', 'semana']
# ['y', 'excelente', 'inicio']
# ['y', 'excelente', 'semana']
# ['@usuario', 'excelente', 'semana']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'fin']
# ['un', 'excelente', 'inicio']
# []
# ['un', 'excelente', 'inicio']
# ['mano', 'excelente', 'inicio']
# []
# []
# ['y', 'excelente', 'semana']
# []
# []
# ['@usuario', 'excelente', 'comienzo']
# ['con', 'excelente', 'actitud']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'inicio']
# ['con', 'excelente', 'informacion']
# []
# []
# ['derechos', 'excelente', 'informacion']
# ['una', 'excelente', 'memoria']
# ['una', 'excelente', 'semana']
# ['@usuario', 'excelente', 'texto']
# ['días', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'lunes']
# ['una', 'excelente', 'y']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['y', 'excelente', 'semana']
# ['tengas', 'excelente', 'dia']
# ['@usuario', 'excelente', 'artículo']
# ['una', 'excelente', 'semana']
# ['y', 'excelente', 'video']
# ['bellisima', 'excelente', 'informacion']
# []
# []
# []
# []
# []
# []
# ['una', 'excelente', 'tarde']
# ['matata', 'excelente', 'artista']
# []
# ['servirle', 'excelente', 'tarde']
# ['con', 'excelente', 'calidad']
# ['esta', 'excelente', 'experiencia']
# ['manera', 'excelente', '@']
# ['ana', 'excelente', 'tanto']
# ['gracias', 'excelente', 'observación']
# []
# []
# ['favor', 'excelente', 'día']
# ['olviden', 'excelente', 'análisis']
# ['@usuario', 'excelente', 'columna']
# ['hermano', 'excelente', 'tarde']
# ['sobra', 'excelente', 'semana']
# []
# []
# ['un', 'excelente', 'inicio']
# []
# []
# []
# []
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['de', 'excelente']
# ['una', 'excelente', 'tarde']
# ['@usuario', 'excelente', 'comienzo']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'día']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'participación']
# ['_number', 'excelente', 'obra']
# []
# ['una', 'excelente', 'causa']
# ['guapa', 'excelente', 'noticiero']
# ['y', 'excelente', 'informacion']
# []
# ['oficinas', 'excelente', '…']
# []
# []
# ['@usuario', 'excelente', 'muchas']
# ['pases', 'excelente', 'lunes']
# []
# ['sería', 'excelente', 'que']
# ['@usuario', 'excelente', 'comida']
# ['😭', 'excelente', 'rola']
# ['una', 'excelente', 'actriz']
# []
# ['hermosa', 'excelente', 'conductora']
# ['hombre', 'excelente', 'que']
# ['@usuario', 'excelente', 'programa']
# ['una', 'excelente', 'obra']
# ['ten', 'excelente', 'sueño']
# ['un', 'excelente', 'inicio']
# []
# ['@usuario', 'excelente', 'reflexión']
# ['@usuario', 'excelente', 'trabajo']
# []
# ['un', 'excelente', 'grupo']
# ['un', 'excelente', 'diseñador']
# ['listo', 'excelente', 'noche']
# ['un', 'excelente', 'martes']
# []
# ['🐒', 'excelente', '…']
# ['un', 'excelente', 'día']
# ['eres', 'excelente', 'conductora']
# ['un', 'excelente', 'periodista']
# ['una', 'excelente', 'ortografía']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['#t909', 'excelente', 'bloque']
# ['bellisima', 'excelente', 'informacion']
# ['tuiteros', 'excelente', 'día']
# ['super', 'excelente', 'día']
# []
# ['con', 'excelente', 'informacion']
# []
# ['un', 'excelente', 'mar']
# ['pases', 'excelente', 'martes']
# ['y', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['nothing', 'excelente', 'versión']
# ['un', 'excelente', 'método']
# ['trabajar', 'excelente', 'día']
# ['día', 'excelente', 'martes']
# ['#antoniopampliegaenlacafetera', 'excelente', 'relato']
# ['una', 'excelente', 'noche']
# []
# ['@usuario', 'excelente', 'reflexión']
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['pasala', 'excelente', 'en']
# []
# []
# ['un', 'excelente', 'día']
# []
# ['@usuario', 'excelente', '#penademuerteya']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['tenga', 'excelente', 'marte']
# ['con', 'excelente', 'informaci']
# []
# ['clínica', 'excelente', 'grupo']
# ['un', 'excelente', 'y']
# ['un', 'excelente', 'precio']
# []
# ['salga', 'excelente', '🤗']
# []
# ['es', 'excelente', 'día']
# ['una', 'excelente', 'mañana']
# ['un', 'excelente', 'martes']
# []
# ['@usuario', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['oliva', 'excelente', 'la']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'martes']
# ['con', 'excelente', 'relación']
# ['y', 'excelente', '…']
# ['y', 'excelente', 'martes']
# ['una', 'excelente', 'opción']
# ['una', 'excelente', 'tarde']
# ['saludos', 'excelente', 'la']
# ['un', 'excelente', 'y']
# ['@usuario', 'excelente', 'artículo']
# []
# ['un', 'excelente', 'martes']
# ['otago', 'excelente', 'lugar']
# []
# ['un', 'excelente', 'martes']
# ['una', 'excelente', 'semana']
# ['de', 'excelente', 'calidad']
# ['un', 'excelente', 'martes']
# ['una', 'excelente', 'atención']
# ['@usuario', 'excelente', 'equ']
# ['directora', 'excelente', 'día']
# []
# []
# []
# ['algo', 'excelente', 'me']
# ['@usuario', 'excelente', 'trabajo']
# ['es', 'excelente', '…']
# []
# ['@usuario', 'excelente', 'gráfico']
# ['sierra', 'excelente', 'día']
# []
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'ganador']
# ['@usuario', 'excelente', 'relación']
# ['vida', 'excelente', 'tarde']
# []
# ['su', 'excelente', 'su']
# []
# ['@usuario', 'excelente', 'atención']
# []
# ['especialestd', 'excelente', 'convivencia']
# []
# []
# ['un', 'excelente', 'amante']
# ['@usuario', 'excelente', 'felicitaciones']
# ['una', 'excelente', 'noche']
# ['con', 'excelente', 'playlist']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'amante']
# ['sea', 'excelente', 'pero']
# ['#retoaradia5', 'excelente', 'esfuerzo']
# ['#retoaradia5', 'excelente', 'esfuerzo']
# ['vida', 'excelente', 'correlación']
# []
# []
# ['un', 'excelente', 'día']
# []
# ['una', 'excelente', 'velada']
# ['un', 'excelente', 'martes']
# ['bellisima', 'excelente', 'pograma']
# ['tengan', 'excelente', 'noche']
# ['día', 'excelente', 'para']
# ['día', 'excelente', 'para']
# ['casas', 'excelente', 'luchadores']
# ['@usuario', 'excelente', 'noticia']
# ['@usuario', 'excelente', 'escuchar']
# ['@usuario', 'excelente', 'equipo']
# ['sido', 'excelente', '💜']
# ['caigo', 'excelente', 'jajajajaja']
# ['un', 'excelente', 'año']
# ['un', 'excelente', 'miércoles']
# []
# ['servirle', 'excelente', 'día']
# ['un', 'excelente', 'miércoles']
# []
# ['y', 'excelente', 'miércoles']
# ['@usuario', 'excelente', 'idea']
# ['un', 'excelente', 'día']
# ['uno', 'excelente', '#buenosdias']
# ['y', 'excelente', 'miercoles']
# ['hola', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'miércoles']
# ['y', 'excelente', 'jornada']
# ['propuesta', 'excelente', 'aunque']
# ['un', 'excelente', 'día']
# []
# ['un', 'excelente', 'día']
# ['servirle', 'excelente', 'día']
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['tengas', 'excelente', 'día']
# []
# ['tengan', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', '#miercoles']
# ['un', 'excelente', 'día']
# ['empezando', 'excelente', 'el']
# ['dra', 'excelente', 'día']
# ['un', 'excelente', 'miércoles']
# ['#felizmiercoles', 'excelente', 'baile']
# []
# ['un', 'excelente', '#miercoles']
# []
# []
# ['@usuario', 'excelente', 'oswaldo']
# ['servirle', 'excelente', 'día']
# ['encuentren', 'excelente', 'y']
# ['#efectograndeza', 'excelente', 'dia']
# ['un', 'excelente', 'ejemplo']
# ['la', 'excelente', 'exposición']
# ['una', 'excelente', 'mañana']
# []
# ['una', 'excelente', 'tarde']
# ['tiene', 'excelente', 'libros']
# ['será', 'excelente', '😃']
# ['guapo', 'excelente', 'miércoles']
# ['una', 'excelente', 'labor']
# ['un', 'excelente', 'y']
# ['@usuario', 'excelente', 'estaremos']
# ['servirle', 'excelente', 'tarde']
# ['@usuario', 'excelente', 'candidato']
# []
# ['qué', 'excelente', 'noticia']
# ['un', 'excelente', 'miércoles']
# ['ti', 'excelente', 'día']
# ['@usuario', 'excelente', 'atención']
# ['en', 'excelente', 'estado']
# ['una', 'excelente', 'opción']
# ['@usuario', 'excelente', 'lo']
# ['@usuario', 'excelente', 'reflexión']
# ['ella', 'excelente', 'tarde']
# ['contigo', 'excelente', 'energía']
# ['una', 'excelente', 'idea']
# ['bellisima', 'excelente', 'informacion']
# ['valle', 'excelente', 'servicio']
# ['guapa', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'informacion']
# ['estuvo', 'excelente', '@usuario']
# ['tiburones', 'excelente', 'experiencia']
# ['decepción', 'excelente', 'candidato']
# ['y', 'excelente']
# ['doctor', 'excelente', 'cátedra']
# ['🙈', 'excelente']
# ['salió', 'excelente']
# ['ti', 'excelente', 'cierre']
# ['@usuario', 'excelente', 'comida']
# []
# []
# ['sr', 'excelente', 'trabajo']
# []
# ['con', 'excelente', 'informacion']
# ['pase', 'excelente', 'noche']
# ['con', 'excelente', 'entrevista']
# ['pero', 'excelente', 'no']
# ['@usuario', 'excelente', 'foto']
# ['atención', 'excelente']
# ['@usuario', 'excelente', 'desafío']
# []
# ['una', 'excelente', 'noche']
# ['cena', 'excelente', 'compañía']
# ['@usuario', 'excelente', 'calidad']
# ['un', 'excelente', 'día']
# []
# ['un', 'excelente', 'miércoles']
# ['@usuario', 'excelente', 'detalle']
# ['el', 'excelente', 'programa']
# ['sale', 'excelente', 'eso']
# ['una', 'excelente', 'noche']
# ['tengan', 'excelente', 'noche']
# ['pd', 'excelente', 'trabajo']
# []
# ['un', 'excelente', 'candidato']
# ['fue', 'excelente', 'porque']
# ['vida', 'excelente', 'compañía']
# ['🙌', 'excelente', 'elección']
# ['un', 'excelente', 'trabajo']
# ['@usuario', 'excelente', 'inicio']
# []
# ['un', 'excelente', 'inicio']
# []
# ['hermosa', 'excelente', 'informacion']
# ['controlarlos', 'excelente', 'jueves']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'conductora']
# ['igualmente', 'excelente', 'día']
# ['@usuario', 'excelente', 'empresa']
# ['con', 'excelente', 'informacion']
# ['y', 'excelente', 'jueves']
# ['actitud', 'excelente', 'dia']
# ['hermosa', 'excelente', 'informacion']
# []
# ['servirle', 'excelente', 'día']
# ['😏', 'excelente', '#juevesdepecado']
# []
# ['igualmente', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# []
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'mes']
# []
# ['y', 'excelente', 'jueves']
# []
# []
# ['un', 'excelente', 'mes']
# ['cierto', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# ['#juevesdeculpables', 'excelente', 'día']
# []
# []
# ['@usuario', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'inicio']
# []
# ['@usuario', 'excelente', 'programa']
# []
# ['@usuario', 'excelente', 'nos']
# ['con', 'excelente', 'infor']
# []
# ['un', 'excelente', 'día']
# ['gracias', 'excelente', 'servicio']
# ['una', 'excelente', 'forma']
# []
# []
# ['#sinvotonohaydinero', 'excelente', 'trabajo']
# ['saludos', 'excelente', 'jueves']
# ['un', 'excelente', 'cumpleaños']
# ['@usuario', 'excelente', 'concierto']
# ['@usuario', 'excelente', 'noticia']
# ['una', 'excelente', 'madre']
# ['un', 'excelente', 'jueves']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# ['👌', 'excelente', 'tarde']
# []
# ['un', 'excelente', 'libro']
# ['@usuario', 'excelente', 'con']
# []
# ['@usuario', 'excelente', 'libro']
# ['fabulosa', 'excelente', 'precio']
# ['de', 'excelente', 'calidad']
# []
# ['@usuario', 'excelente', 'trabajo']
# []
# ['@usuario', 'excelente', 'princesa']
# ['un', 'excelente', 'día']
# ['de', 'excelente', 'calidad']
# ['un', 'excelente', 'campeón']
# ['@usuario', 'excelente', 'libro']
# ['atención', 'excelente', 'te']
# ['y', 'excelente', 'días']
# ['una', 'excelente', 'periodista']
# []
# ['@usuario', 'excelente', 'idea']
# []
# []
# ['es', 'excelente', 'lo']
# ['@usuario', 'excelente', 'recuerdo']
# ['un', 'excelente', 'amigo']
# []
# []
# ['@usuario', 'excelente', 'respuesta']
# ['@usuario', 'excelente', 'noticia']
# ['una', 'excelente', 'oportunidad']
# ['un', 'excelente', 'lugar']
# ['con', 'excelente', 'informacion']
# ['y', 'excelente', 'calidad']
# ['todo', 'excelente', 'el']
# ['>', 'excelente', 'noche']
# ['un', 'excelente', 'trabajo']
# ['@usuario', 'excelente', 'improvisación']
# ['una', 'excelente', 'cuidadora']
# ['una', 'excelente', 'compañia']
# ['servirle', 'excelente', 'noche']
# ['#dj', 'excelente', '#música']
# ['burrito', 'excelente', '@usuario']
# ['y', 'excelente', 'primer']
# ['increible', 'excelente', 'actuacion']
# ['una', 'excelente', 'sesion']
# ['fue', 'excelente', 'felicidades']
# ['es', 'excelente', 'perfecta']
# ['reina', 'excelente', 'inicio']
# ['un', 'excelente', 'jueves']
# ['hola', 'excelente', 'nos']
# ['bellisima', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'programa']
# []
# ['una', 'excelente', 'noche']
# ['magistral', 'excelente', 'inicio']
# ['una', 'excelente', 'obra']
# ['una', 'excelente', 'serie']
# ['y', 'excelente', 'compañía']
# []
# ['siempre', 'excelente']
# ['@usuario', 'excelente', 'noche']
# ['un', 'excelente', 'muralista']
# ['tengan', 'excelente', 'fin']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', '…']
# ['dias', 'excelente', 'inicio']
# []
# ['un', 'excelente', 'y']
# ['bellisima', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['hermosa', 'excelente', 'extrevista']
# ['un', 'excelente', 'día']
# ['ser', 'excelente', 'programa']
# ['tengan', 'excelente', 'viernes']
# ['un', 'excelente', 'fin']
# ['pasen', 'excelente', 'día']
# ['hermosa', 'excelente', 'informacion']
# ['y', 'excelente', 'informacion']
# ['hermosa', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'día']
# []
# ['todo', 'excelente', '😰']
# ['super', 'excelente', 'día']
# ['@usuario', 'excelente', 'viernes']
# ['y', 'excelente', 'fin']
# ['deseamos', 'excelente', 'inicio']
# []
# ['@s', 'excelente', 'jornada']
# []
# ['tengan', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['hizo', 'excelente']
# ['puebla', 'excelente', 'día']
# ['un', 'excelente', '#frikidia']
# ['un', 'excelente', 'viernes']
# ['felicidades', 'excelente', 'entrevista']
# ['@usuario', 'excelente', 'entrevista']
# ['está', 'excelente', 'rolita']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'viernes']
# ['@usuario', 'excelente', 'noticia']
# ['una', 'excelente', 'serie']
# ['😄', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['y', 'excelente', 'finde']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'día']
# ['chepe', 'excelente']
# []
# []
# ['de', 'excelente', 'calidad']
# ['saldrá', 'excelente', '😏']
# ['tenga', 'excelente', 'fin']
# ['tengan', 'excelente', 'día']
# []
# ['@usuario', 'excelente', 'amigo']
# ['un', 'excelente', 'fin']
# ['@usuario', 'excelente', 'la']
# []
# ['un', 'excelente', 'fin']
# ['@usuario', 'excelente', 'observación']
# ['mundial', 'excelente', 'música']
# ['@usuario', 'excelente', 'observación']
# ['soy', 'excelente', '👨']
# []
# ['una', 'excelente', 'opción']
# ['@usuario', 'excelente', 'reflexión']
# ['viernes']
# ['estuviste', 'excelente', 'gracias']
# ['fácil', 'excelente', 'respuesta']
# []
# ['@usuario', 'excelente', 'foto']
# []
# ['y', 'excelente', 'fin']
# ['un', 'excelente', 'macha']
# ['todo', 'excelente', 'sencilla']
# ['en', 'excelente', '…']
# ['gracias', 'excelente', 'noche']
# ['un', 'excelente', 'dia']
# ['@usuario', 'excelente', 'reflexión']
# ['tardes', 'excelente', 'fin']
# ['tardes', 'excelente', 'fin']
# ['que', 'excelente', 'estuvieron']
# ['y', 'excelente', '#finde']
# ['@usuario', 'excelente', 'fin']
# ['un', 'excelente', 'motivo']
# []
# ['tardes', 'excelente', 'fin']
# ['amigos', 'excelente', 'fin']
# ['hizo', 'excelente', 'interpretación']
# ['@usuario', 'excelente', 'servicio']
# ['y', 'excelente', 'compañía']
# ['labores', 'excelente', 'y']
# ['@usuario', 'excelente', 'programa']
# ['amarillo', 'excelente', 'combinación']
# ['con', 'excelente', 'compañía']
# []
# ['tu', 'excelente', 'trabajo']
# ['teatro', 'excelente', 'con']
# ['@usuario', 'excelente', 'programa']
# ['un', 'excelente', 'viernes']
# ['una', 'excelente', 'opción']
# []
# []
# ['con', 'excelente', 'informacion']
# ['sí', 'excelente']
# ['️', 'excelente', 'tu']
# ['es', 'excelente', 'url']
# ['guapa', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'pograma']
# ['tsi', 'excelente', 'balance']
# ['el', 'excelente', 'concierto']
# ['🏼', 'excelente', '@']
# ['fue', 'excelente', 'con']
# ['chavos', 'excelente', 'sábado']
# []
# ['@usuario', 'excelente', 'fin']
# []
# ['un', 'excelente', 'día']
# ['url', 'excelente', 'día']
# ['mejor', 'excelente', '#sabadodeganarseguidores']
# ['espera', 'excelente', 'sábado']
# ['☀', 'excelente', 'sábado']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente']
# ['bellisima', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'sábado']
# ['un', 'excelente', 'sábado']
# ['❤', 'excelente', 'sábado']
# ['@usuario', 'excelente', 'si']
# ['amarte', 'excelente', 'tuit']
# []
# ['un', 'excelente', 'y']
# []
# ['de', 'excelente', 'y']
# []
# ['@usuario', 'excelente', 'reflexión']
# ['@usuario', 'excelente', 'reflexión']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['#choche', 'excelente', 'sábado']
# ['cafecito', 'excelente', 'amigos']
# ['un', 'excelente', 'fin']
# ['@usuario', 'excelente', 'evento']
# ['#championsxfox', 'excelente', 'transmisión']
# ['un', 'excelente', 'single']
# ['jajajajaja', 'excelente', 'gracias']
# []
# ['⭐', 'excelente', 'por']
# ['@usuario', 'excelente', 'noticia']
# ['una', 'excelente', 'suavidad']
# ['comentarios', 'excelente', 'transmisión']
# []
# ['@usuario', 'excelente', 'conferencia']
# ['un', 'excelente', 'sabado']
# ['un', 'excelente', 'sábado']
# ['la', 'excelente', 'transmisión']
# ['✊', 'excelente', 'elección']
# []
# []
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'servicio']
# ['esta', 'excelente', 'entrevista']
# []
# []
# []
# ['jaume', 'excelente', '#retoaradia6']
# []
# ['@usuario', 'excelente', 'concierto']
# []
# []
# ['niegan', 'excelente', 'artículo']
# ['@usuario', 'excelente', 'cobertura']
# []
# ['salir', 'excelente', 'confío']
# ['una', 'excelente', 'alcachofa']
# ['🏻', 'excelente', 'servicio']
# ['simplemente', 'excelente', 'los']
# ['tardes', 'excelente', 'fin']
# ['la', 'excelente', 'transmisión']
# []
# ['@usuario', 'excelente', 'url']
# []
# ['@usuario', 'excelente', 'comida']
# ['lópez']
# ['tan', 'excelente', 'labor']
# []
# []
# ['sería', 'excelente', 'sacar']
# ['vih', 'excelente', 'obra']
# ['seria', 'excelente', 'es']
# ['guapa', 'excelente', 'conduct']
# ['hermosa', 'excelente', 'pograma']
# ['verte', 'excelente', 'noche']
# ['un', 'excelente', 'equipo']
# ['un', 'excelente', 'sábado']
# ['noguez', 'excelente', 'el']
# []
# ['#losjuguetesenfarandula', 'excelente', 'programa']
# []
# []
# ['@usuario', 'excelente', 'trabajo']
# ['estaría', 'excelente', 'si']
# ['@usuario', 'excelente', 'como']
# []
# ['un', 'excelente', 'cumpleaños']
# []
# ['@usuario', 'excelente', 'organizacion']
# ['atenciones', 'excelente', 'lugar']
# ['atenciones', 'excelente', 'lugar']
# ['de', 'excelente', 'calidad']
# []
# ['mañana', 'excelente', 'domingo']
# []
# ['un', 'excelente', 'domingo']
# ['que', 'excelente', 'óptica']
# ['una', 'excelente', 'idea']
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'y']
# ['día', 'excelente', '#sunday']
# ['un', 'excelente', 'día']
# ['amar', 'excelente', '…']
# ['un', 'excelente', 'día']
# ['provecho', 'excelente', 'domingo']
# ['nevada', 'excelente', 'domingo']
# ['un', 'excelente', 'ejemplo']
# ['@s', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['😁', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['@usuario', 'excelente', 'ruta']
# ['#wonderwoman', 'excelente', 'película']
# []
# ['alex', 'excelente', 'carrera']
# ['tú', 'excelente', 'se']
# ['orozco', 'excelente', '@']
# ['éste', 'excelente', 'programa']
# ['y', 'excelente', 'día']
# ['medina', 'excelente', 'conferencia']
# ['@tedxpolanco', 'excelente', 'tu']
# ['@usuario', 'excelente', 'tu']
# ['un', 'excelente', 'domingo']
# ['#micromachismos', 'excelente', 'domingo']
# []
# []
# ['@usuario', 'excelente', 'show']
# ['el', 'excelente', 'fin']
# ['es', 'excelente', 'con']
# []
# ['potente', 'excelente', 'show']
# []
# ['un', 'excelente', 'dibujo']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'noche']
# ['y', 'excelente', 'informacion']
# ['bellisima', 'excelente', 'reportaje']
# ['#holajunio', 'excelente', 'tarde']
# []
# ['películas', 'excelente', 'domingo']
# ['@usuario', 'excelente', 'playera']
# ['cordiales', 'excelente', 'atardecer']
# ['saludarlos', 'excelente', 'tarde']
# ['felicidades', 'excelente', 'trabajo']
# []
# ['twitter', 'excelente', 'inicio']
# []
# ['realizada', 'excelente', 'fotografía']
# ['electrónica', 'excelente', 'domingo']
# []
# ['gracias', 'excelente', 'función']
# []
# ['pinta', 'excelente', 'mañana']
# []
# []
# ['😃', 'excelente', 'trabajo']
# ['hundido', 'excelente', 'trabajo']
# ['noches', 'excelente', 'inicio']
# ['está', 'excelente', 'la']
# ['un', 'excelente', 'fin']
# ['de', 'excelente', 'comunicación']
# ['@usuario', 'excelente', 'labor']
# ['total', 'excelente', 'corrección']
# ['un', 'excelente', 'día']
# ['una', 'excelente', 'transmisión']
# []
# ['una', 'excelente', 'líder']
# ['su', 'excelente', 'gráfica']
# ['una', 'excelente', 'persona']
# ['una', 'excelente', 'amistad']
# ['@usuario', 'excelente', 'persona']
# ['carmelita', 'excelente', 'lunes']
# ['lunes', 'excelente', 'inicio']
# []
# ['un', 'excelente', 'inicio']
# ['y', 'excelente', 'semana']
# ['con', 'excelente', 'informa']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'semana']
# ['con', 'excelente', 'informacion']
# ['una', 'excelente', 'semana']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['divertiré', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['que', 'excelente', 'semana']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# [':)', 'excelente', 'inicio']
# ['ellas', 'excelente', 'lunes']
# ['un', 'excelente', 'comienzo']
# ['amigos', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# []
# ['servirle', 'excelente', 'día']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['acuerdo', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['tenga', 'excelente', 'día']
# ['un', 'excelente', 'inicio']
# ['@s', 'excelente', 'jornada']
# []
# ['#laalegriadevivir', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['una', 'excelente', 'semana']
# []
# []
# ['@usuario', 'excelente', 'inicio']
# ['una', 'excelente', 'semana']
# ['un', 'excelente', 'comienzo']
# ['y', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# []
# ['ser', 'excelente', 'semana']
# ['un', 'excelente', 'comienzo']
# []
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'día']
# []
# []
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['una', 'excelente', 'semana']
# []
# ['un', 'excelente', 'inicio']
# ['#buenosdias', 'excelente', 'lunes']
# []
# ['también', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'movimiento']
# ['señores', 'excelente', 'inicio']
# ['y', 'excelente', 'inicio']
# ['un', 'excelente', 'comienzo']
# ['@usuario', 'excelente', 'exposición']
# ['un', 'excelente', 'inicio']
# ['listo', 'excelente', 'inicio']
# []
# ['@usuario', 'excelente', 'noticia']
# []
# []
# []
# ['un', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'inicio']
# []
# ['alma', 'excelente', 'inicio']
# ['y', 'excelente', 'inicio']
# []
# ['hermosa', 'excelente', 'informacion']
# ['#elecciones2017', 'excelente', 'participacion']
# ['un', 'excelente', 'inicio']
# []
# ['y', 'excelente', 'semana']
# []
# []
# ['foto', 'excelente', 'trabajo']
# ['&', 'excelente', 'semana']
# []
# ['@usuario', 'excelente', 'pegado']
# ['gracias', 'excelente', 'día']
# ['@usuario', 'excelente', 'toma']
# ['un', 'excelente', 'día']
# ['mancuerna', 'excelente', 'ojalá']
# []
# ['😧', 'excelente', 'estrategia']
# []
# ['entusiasmo', 'excelente', 'lunes']
# []
# []
# []
# []
# ['un', 'excelente', 'día']
# ['estaría', 'excelente', 'url']
# ['@usuario', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['una', 'excelente', 'semana']
# ['y', 'excelente', '…']
# ...
# ['#comunidadcanainpa', 'excelente', 'inicio']
# ['un', 'excelente', 'día']
# []
# []
# ['creador', 'excelente', 'semana']
# []
# ['😘', 'excelente', 'inicio']
# ['de', 'excelente', 'calidad']
# ['un', 'excelente', 'comienzo']
# ['un', 'excelente', 'comienzo']
# ['pm', 'excelente', 'día']
# ['una', 'excelente', 'opción']
# ['el', 'excelente', 'los']
# ['un', 'excelente', 'lunes']
# ['pases', 'excelente', 'lunes']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'lunes']
# ['@usuario', 'excelente', 'que']
# []
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['un', 'excelente', 'inicio']
# ['una', 'excelente', 'obra']
# ['tengan', 'excelente', 'semana']
# ['@usuario', 'excelente', 'inicio']
# ['@usuario', 'excelente', 'semana']
# ['un', 'excelente', 'servicio']
# ['ambos', 'excelente', 'día']
# ['una', 'excelente', 'promoción']
# ['y', 'excelente', 'informacion']
# []
# []
# ['tan', 'excelente', 'programa']
# ['seguirlo', 'excelente', 'día']
# ['una', 'excelente', 'manera']
# []
# ['del', 'excelente', 'curso']
# ['una', 'excelente', 'entrevista']
# ['contaré', 'excelente', 'inicio']
# ['mil', 'excelente', 'historial']
# ['un', 'excelente', 'regalo']
# ['un', 'excelente', 'inicio']
# ['legado', 'excelente', 'mapa']
# ['un', 'excelente', 'día']
# ['tengan', 'excelente', 'gira']
# ['conocelas', 'excelente', 'ubicación']
# []
# ['🌹', 'excelente', 'martes']
# []
# ['extracciones', 'excelente', 'show']
# ['esta', 'excelente', 'serie']
# []
# ['@usuario', 'excelente', 'análisis']
# []
# ['@usuario', 'excelente', 'tarde']
# ['quedaría', 'excelente', 'con']
# ['@usuario', 'excelente', 'noche']
# []
# ['#dj', 'excelente', '#música']
# []
# ['un', 'excelente', 'actor']
# []
# ['cordiales', 'excelente', 'noche']
# ['un', 'excelente', 'inicio']
# []
# ['y', 'excelente', 'descanso']
# ['guapa', 'excelente', 'pograma']
# ['la', 'excelente', 'jornada']
# ['la', 'excelente', 'jornada']
# ['una', 'excelente', 'noche']
# ['pases', 'excelente', 'lunes']
# ['mucho', 'excelente', 'papi']
# ['bellisima', 'excelente', 'pograma']
# ['un', 'excelente', 'día']
# ['y', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['eres', 'excelente', 'y']
# ['mateache', 'excelente', 'recomendación']
# ['guapa', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'martes']
# ['afecto', 'excelente', 'martes']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'martes']
# ['y', 'excelente', 'informacion']
# ['un', 'excelente', 'y']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'martes']
# ['y', 'excelente', 'martes']
# ['con', 'excelente', 'informacion']
# ['un', 'excelente', 'y']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'y']
# ['jajajjaja', 'excelente', 'día']
# ['un', 'excelente', 'y']
# ['día', 'excelente', 'martes']
# ['@s', 'excelente', 'jornada']
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'día']
# ['días', 'excelente', 'elección']
# ['un', 'excelente', 'y']
# ['martes']
# ['un', 'excelente', 'martes']
# []
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'y']
# ['dia', 'excelente', '😎']
# ['@usuario', 'excelente', 'entrevista']
# ['un', 'excelente', 'y']
# ['un', 'excelente', 'martes']
# []
# []
# ['un', 'excelente', 'martes']
# ['un', 'excelente', 'y']
# ['un', 'excelente', 'y']
# ['un', 'excelente', 'y']
# []
# ['@usuario', 'excelente', 'entrevista']
# []
# ['día', 'excelente', 'martes']
# ['@usuario', 'excelente', 'claro']
# ['@usuario', 'excelente', 'día']
# ['pie', 'excelente', 'martes']
# ['y', 'excelente', 'martes']
# ['con', 'excelente', 'informacion']
# ['este', 'excelente', 'trabajo']
# ['día', 'excelente', '❣']
# ['albert', 'excelente', 'martes']
# ['y', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['maestro', 'excelente', 'inspira']
# []
# []
# ['margarita', 'excelente', 'articulo']
# ['@usuario', 'excelente', 'no']
# ['@usuario', 'excelente', 'entrevista']
# ['pases', 'excelente', 'martes']
# ['@usuario', 'excelente', 'día']
# ['una', 'excelente', '…']
# []
# ['amigo', 'excelente', 'tarde']
# ['su', 'excelente', 'programa']
# ['_number', 'excelente', 'evento']
# ['@usuario', 'excelente', 'tarde']
# ['semifinal', 'excelente', 'transmisión']
# []
# ['este', 'excelente', 'equipo']
# ['este', 'excelente', 'equipo']
# ['sería', 'excelente', 'url']
# []
# ['un', 'excelente', 'anti-oxidante']
# ['un', 'excelente', 'día']
# ['felicidad', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['saludos', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['@usuario', 'excelente', 'elemento']
# ['amigo', 'excelente', 'toma']
# ['una', 'excelente', 'persona']
# ['tengas', 'excelente', 'tarde']
# []
# ['suena', 'excelente', '🤔']
# []
# []
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['#playerasrm', 'excelente', 'servicio']
# ['y', 'excelente', 'servicio']
# ['un', 'excelente', 'miércoles']
# ['#elderechodegilborja', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'idea']
# ['el', 'excelente', 'desarro']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'amigo']
# ['un', 'excelente', '#compositor']
# ['una', 'excelente', 'noche']
# ['@usuario', 'excelente', 'trabajo']
# ['#dj', 'excelente', '…']
# []
# []
# ['loreto', 'excelente', 'eso']
# []
# ['cordiales', 'excelente', 'noche']
# ['🎂', 'excelente', 'noche']
# ['cordiales', 'excelente', 'noche']
# []
# ['de', 'excelente', 'ayuda']
# ['jajaja', 'excelente', 'url']
# ['candidato', 'excelente', 'e']
# ['es', 'excelente', 'url']
# ['un', 'excelente', 'martes']
# ['grupo', 'excelente', 'cumplido']
# ['y', 'excelente', 'conductora']
# ['un', 'excelente', 'anuncio']
# []
# ['un', 'excelente', 'plan']
# ['@usuario', 'excelente', 'noche']
# ['estuvo', 'excelente', '👌']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'cobertura']
# []
# ['jajaja', 'excelente', 'programa']
# ['estuvo', 'excelente', '@']
# ['interesante', 'excelente', 'noche']
# ['@usuario', 'excelente', 'canción']
# ['méxico', 'excelente', 'evento']
# []
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# []
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# ['guapa', 'excelente', 'conductora']
# ['algo', 'excelente', 'está']
# ['algo', 'excelente', 'está']
# []
# ['un', 'excelente', 'soundtrack']
# ['mejor', 'excelente', 'canción']
# ['@usuario', 'excelente', 'dia']
# []
# ['pases', 'excelente', 'y']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'miércoles']
# ['un', 'excelente', 'día']
# ['tengan', 'excelente', 'miércoles']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['felicidades', 'excelente', 'mamá']
# []
# []
# ['un', 'excelente', 'día']
# []
# ['dia', 'excelente', 'con']
# ['mil', 'excelente', 'historial']
# ['mil', 'excelente', 'historial']
# ['mil', 'excelente', 'historial']
# ['mil', 'excelente', 'historial']
# ['perfectos', 'excelente', '…']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'sencillo']
# []
# ['tengas', 'excelente', 'día']
# ['pasen', 'excelente', 'bendiciones']
# ['❤', 'excelente', 'miércoles']
# []
# ['una', 'excelente', 'madre']
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'presidente']
# []
# ['un', 'excelente', 'día']
# ['@usuario', 'excelente', 'y']
# ['un', 'excelente', 'd']
# ['efecto', 'excelente', 'conferencia']
# ['un', 'excelente', 'día']
# ['y', 'excelente', 'trabajo']
# ['una', 'excelente', 'madre']
# ['de', 'excelente', 'salud']
# []
# ['preguntar', 'excelente', 'artículo']
# []
# ['una', 'excelente', 'conferencia']
# ['es', 'excelente', 'merece']
# ['una', 'excelente', 'idea']
# ['@usuario', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# []
# ['angel', 'excelente', 'día']
# []
# ['2-0', 'excelente', 'fuera']
# ['un', 'excelente', 'periodista']
# []
# ['en', 'excelente', 'estado']
# ['una', 'excelente', 'tarde']
# ['niños', 'excelente', 'día']
# []
# [':)', 'excelente', 'pero']
# ['capacitación', 'excelente', '#vamosxmas']
# ['😍', 'excelente', 'cuenta']
# ['un', 'excelente', 'martes']
# ['y', 'excelente', 'miercoles']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente', 'descripción']
# ['que', 'excelente', 'programa']
# ['tu', 'excelente', 'suerte']
# ['y', 'excelente', 'informacion']
# ['comienzo']
# ['@usuario', 'excelente', 'discurso']
# ['un', 'excelente', 'día']
# ['bueno', 'excelente', 'trabajo']
# ['y', 'excelente', 'fútbol']
# ['@usuario', 'excelente', '#publicacion']
# ['pase', 'excelente', 'noche']
# ['otro', 'excelente', 'día']
# ['una', 'excelente', 'noche']
# ['aficionacos', 'excelente', 'regalo']
# ['un', 'excelente', 'miércoles']
# []
# ['un', 'excelente', 'día']
# ['#donelias', 'excelente', 'actuación']
# ['está', 'excelente', 'qué']
# ['#riverdale', 'excelente', 'recomendación']
# []
# ['una', 'excelente', 'niche']
# ['papel', 'excelente', '#dafbama2017_exo']
# ['guapa', 'excelente', 'informacion']
# ['🔴', 'excelente', 'asistencia']
# ['@usuario', 'excelente', '2da']
# ['tan', 'excelente', 'trabajo']
# ['bellisima', 'excelente', 'conductora']
# ['un', 'excelente', 'homenaje']
# ['verdad', 'excelente', 'trabajo']
# ['el', 'excelente', 'artista']
# []
# []
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# ['@usuario', 'excelente', 'tu']
# []
# ['cordiales', 'excelente', 'jueves']
# ['tengas', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['con', 'excelente', 'informacion']
# ['tengas', 'excelente', 'día']
# ['@usuario', 'excelente', 'día']
# ['manejando', 'excelente', 'jueves']
# ['un', 'excelente', 'día']
# ['con', 'excelente', 'reportaje']
# ['con', 'excelente', 'sonido']
# ['y', 'excelente', 'jueves']
# ['reversa', 'excelente', 'dia']
# ['un', 'excelente', 'jueves']
# ['con', 'excelente', 'informacion']
# ['servirle', 'excelente', 'día']
# ['un', 'excelente', 'jueves']
# []
# ['un', 'excelente', 'jueves']
# ['un', 'excelente', 'jueves']
# ['amigos', 'excelente', 'día']
# []
# []
# ['días', 'excelente', 'jueves']
# ['terraza', 'excelente', 'día']
# ['servirle', 'excelente', 'día']
# ['días', 'excelente', 'jueves']
# []
# ['precio', 'excelente', 'racing']
# ['un', 'excelente', 'jueves']
# ['@usuario', 'excelente', 'jueves']
# ['un', 'excelente', 'programa']
# ['un', 'excelente', 'jueves']
# ['saludos', 'excelente', 'jueves']
# ['con', 'excelente', 'informacion']
# ['vaya', 'excelente', 'y']
# ['@usuario', 'excelente', 'mi']
# ['eres', 'excelente', 'conductora']
# []
# ['tengan', 'excelente', 'día']
# []
# []
# []
# ['😘', 'excelente', 'programa']
# ['bellisima', 'excelente', 'infornacion']
# ['una', 'excelente', 'reunión']
# ['@usuario', 'excelente', 'su']
# []
# ['😍', 'excelente', 'combinación']
# ['dieta', 'excelente', 'consiste']
# []
# ['👌', 'excelente', 'jueves']
# []
# ['un', 'excelente', 'trabajo']
# ['mucho', 'excelente', 'película']
# ['#colombia', 'excelente', 'oportunidad']
# ['jajajajaja', 'excelente', 'noche']
# ['una', 'excelente', 'opción']
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'jueves']
# ['ella', 'excelente', 'dia']
# ['de', 'excelente', 'calidad']
# ['@usuario', 'excelente']
# ['esta', 'excelente', 'promoción']
# ['chepina', 'excelente', 'tarde']
# []
# ['@usuario', 'excelente', 'a']
# []
# []
# []
# ['uba', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'jueves']
# ['@usuario', 'excelente', 'experimento']
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'cumpleaños']
# ['una', 'excelente', 'noche']
# ['con', 'excelente', 'informacion']
# ['😍', 'excelente', 'tarde']
# ['una', 'excelente', 'opción']
# ['estuvo', 'excelente', 'muy']
# ['_number', 'excelente', 'par']
# ['un', 'excelente', 'día']
# []
# ['wow', 'excelente', 'reunión']
# ['laboral', 'excelente', 'noche']
# []
# ['@usuario', 'excelente', 'función']
# ['pase', 'excelente', 'noche']
# ['@usuario', 'excelente', 'productora']
# ['una', 'excelente', 'reunión']
# ['una', 'excelente', 'actitud']
# []
# ['🙈', 'excelente', 'tarde']
# ['@usuario', 'excelente', 'presentación']
# ['que', 'excelente', 'url']
# ['un', 'excelente', 'jueves']
# []
# ['una', 'excelente', 'rutina']
# ['el', 'excelente', 'festejo']
# ['este', 'excelente', 'disco']
# ['capitalmasarykmx', 'excelente', '#venezuela']
# ['barista', 'excelente', '✔']
# []
# ['vaya', 'excelente', 'sé']
# ['con', 'excelente', 'informacion']
# ['y', 'excelente', 'fin']
# ['una', 'excelente', 'entrevista']
# []
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'viernes']
# ['juventudes', 'excelente', 'foro']
# ['y', 'excelente', 'fin']
# ['envidia', 'excelente', 'fin']
# ['@usuario', 'excelente', 'reflexión']
# ['tengas', 'excelente', 'día']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'café']
# ['tenga', 'excelente', 'viernes']
# ['tengas', 'excelente', 'viernes']
# ['hey', 'excelente', 'dia']
# ['@usuario', 'excelente', 'viernes']
# ['@usuario', 'excelente', 'viernes']
# ['que', 'excelente', 'cierre']
# ['y', 'excelente', 'grabación']
# ['velluditos', 'excelente', 'viernes']
# ['un', 'excelente', '#viernes']
# ['@usuario', 'excelente', 'viernes']
# ['una', 'excelente', 'temporada']
# []
# ['@usuario', 'excelente', 'presentaciones']
# ['@s', 'excelente', 'jornada']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'viernes']
# ['@usuario', 'excelente', 'para']
# ['nirvana', 'excelente', 'día']
# ['crazy-aerosmith', 'excelente', 'día']
# ['un', 'excelente', 'día']
# ['un', 'excelente', 'dia']
# ['un', 'excelente', 'inicio']
# ['&', 'excelente', 'viernes']
# []
# ['#queremosrock', 'excelente', '#felizviernes']
# []
# ['@usuario', 'excelente', '✌']
# ['@usuario', 'excelente', 'día']
# ['pases', 'excelente']
# ['servirle', 'excelente', 'día']
# []
# ['acompañen', 'excelente', 'fin']
# ['un', 'excelente', 'viernes']
# ['todo', 'excelente', 'y']
# ['una', 'excelente', 'entrevista']
# ['una', 'excelente', 'cena']
# []
# ['y', 'excelente', 'fin']
# ['@usuario', 'excelente', 'conferencia']
# ['un', 'excelente', 'curso']
# ['servirle', 'excelente', 'día']
# ['una', 'excelente', 'tarde']
# ['un', 'excelente', 'viernes']
# ['un', 'excelente', 'conductor']
# []
# ['#granfindesemana', 'excelente', 'emisión']
# ['un', 'excelente', 'viernes']
# ['la', 'excelente', 'banda']
# []
# ['@usuario', 'excelente', 'programa']
# []
# ['@usuario', 'excelente', 'me']
# []
# ['un', 'excelente', 'puente']
# []
# ['con', 'excelente', 'informacion']
# ['soy', 'excelente', 'ser']
# ['gaby', 'excelente', 'labor']
# ['servirle', 'excelente', 'día']
# ['una', 'excelente', 'enfermera']
# []
# ['servirle', 'excelente', 'día']
# ['hoy', 'excelente', 'ejercicio']
# []
# ['un', 'excelente', 'fin']
# []
# ['teatro', 'excelente', 'obra']
# ['con', 'excelente', 'informacion']
# ['y', 'excelente', 'fin']
# []
# []
# []
# []
# []
# ['un', 'excelente', 'trabajo']
# ['una', 'excelente', 'dermatóloga']
# ['con', 'excelente', 'informacion']
# ['@usuario', 'excelente']
# ['una', 'excelente', 'noche']
# ['cardiaco', 'excelente', 'cmn']
# ['corruptos', 'excelente', 'papel']
# ['y', 'excelente', 'fin']
# ['y', 'excelente', 'fin']
# ['😔', 'excelente', 'y']
# ['url', 'excelente', 'maestro']
# ['#ladosis', 'excelente', 'grupo']
# ['una', 'excelente', 'pregunta']
# ['un', 'excelente', 'colaborador']
# ['#cumpleaños', 'excelente', 'trabajo']
# ['@usuario', 'excelente', 'foto']
# ['un', 'excelente', 'fin']
# ['con', 'excelente', 'compañía']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['un', 'excelente', 'trabajo']
# ['un', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['este', 'excelente', 'grupo']
# ['y', 'excelente', 'url']
# ['una', 'excelente', 'noche']
# ['una', 'excelente', 'noche']
# ['like', 'excelente', 'para']
# []
# []
# ['con', 'excelente', 'informacion']
# ['=', 'excelente', 'evento']
# ['un', 'excelente', 'fin']
# ['@usuario', 'excelente', 'reggae']
# ['guapa', 'excelente', 'conductora']
# ['una', 'excelente', 'amiga']
# ['bellisima', 'excelente', 'conductora']
# ['una', 'excelente', 'noche']
# []
# ['un', 'excelente', 'viernes']
# ['y', 'excelente', 'fin']
# []
# ['pero', 'excelente', 'respuesta']
# ['un', 'excelente', 'sábado']
# []
# ['un', 'excelente', 'finde']
# ['con', 'excelente', 'entrevista']
# ['días', 'excelente', 'bendecido']
# ['@usuario', 'excelente', 'día']
# ['un', 'excelente', 'nivel']
# ['con', 'excelente', 'informacion']
# ['#sabadodeninasmalas', 'excelente', 'día']
# ['un', 'excelente', 'y']
# ['😊', 'excelente', 'sábado']
# ['un', 'excelente', 'fin']
